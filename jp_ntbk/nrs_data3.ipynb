# %%
import numpy as np
import pandas as pd

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header = 0)[2]
df2 = pd.read_html(link, header = 0)[3]
df3 = pd.read_html(link, header = 0)[4]
df4 = pd.read_html(link, header = 0)[5]

# %%
df1.head(1)
# Out:
#          Opening  Opening.1                    Title  \
# 0  J A N U A R Y          5  Insidious: The Last Key
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Leigh Whannell (scree...  [2]

# %%
df2.head(1)
# Out:
#      Opening  Opening.1          Title  \
# 0  A P R I L          6  A Quiet Place
#
#                                   Production company  \
# 0  Paramount Pictures / Platinum Dunes / Sunday N...
#
#                                        Cast and crew  Ref.
# 0  John Krasinski (director/screenplay); Bryan Wo...  [60]

# %%
df3.head(1)
# Out:
#    Opening  Opening.1                  Title  \
# 0  J U L Y          3  Who's Watching Oliver
#
#                    Production company  \
# 0  Motionpictures / Gravitas Ventures
#
#                                        Cast and crew   Ref.
# 0  Richie Moore (director/screenplay); Raimund Hu...  [115]

# %%
df4.head(1)
# Out:
#          Opening  Opening.1  Title                        Production company  \
# 0  O C T O B E R          5  Venom  Columbia Pictures / Marvel Entertainment
#
#                                        Cast and crew   Ref.
# 0  Ruben Fleischer (director); Jeff Pinkner, Scot...  [183]

# %%
df = pd.concat([df1, pd.concat([df2, pd.concat([df3, df4], ignore_index = True)], ignore_index = True)], ignore_index = True)
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 245  D E C E M B E R         21               Second Act
# 246  D E C E M B E R         25          Holmes & Watson
# 247  D E C E M B E R         25                     Vice
# 248  D E C E M B E R         25      On the Basis of Sex
# 249  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 245                                  STX Entertainment
# 246  Columbia Pictures / Gary Sanchez Productions /...
# 247          Annapurna Pictures / Plan B Entertainment
# 248                                     Focus Features
# 249                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 245  Peter Segal (director); Justin Zackham, Elaine...  [239]
# 246  Etan Cohen (director/screenplay); Will Ferrell...  [143]
# 247  Adam McKay (director/screenplay); Christian Ba...  [118]
# 248  Mimi Leder (director); Daniel Stiepleman (scre...  [208]
# 249  Karyn Kusama (director); Phil Hay, Matt Manfre...  [240]
#
# [250 rows x 6 columns]

# %%
pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in /opt/anaconda3/lib/python3.12/site-packages (1.9.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from tmdbv3api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->tmdbv3api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->tmdbv3api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->tmdbv3api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->tmdbv3api) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '7d0d645c09f193f20fdb0a6e4cd50663'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genres_str = " "
        for i in range(0, len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genres_str.join(genres)
    else:
        np.NAN

# %%
df['genres'] = df['Title'].map(lambda x : get_genre(str(x)))
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 245  D E C E M B E R         21               Second Act
# 246  D E C E M B E R         25          Holmes & Watson
# 247  D E C E M B E R         25                     Vice
# 248  D E C E M B E R         25      On the Basis of Sex
# 249  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 245                                  STX Entertainment
# 246  Columbia Pictures / Gary Sanchez Productions /...
# 247          Annapurna Pictures / Plan B Entertainment
# 248                                     Focus Features
# 249                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 245  Peter Segal (director); Justin Zackham, Elaine...  [239]
# 246  Etan Cohen (director/screenplay); Will Ferrell...  [143]
# 247  Adam McKay (director/screenplay); Christian Ba...  [118]
# 248  Mimi Leder (director); Daniel Stiepleman (scre...  [208]
# 249  Karyn Kusama (director); Phil Hay, Matt Manfre...  [240]
#
#                                         genres
# 0                              Horror Thriller
# 1                               Thriller Drama
# 2                      Action Thriller Mystery
# 3                        Thriller Action Crime
# 4                  Action Drama Crime Thriller
# ..                                         ...
# 245                             Romance Comedy
# 246               Drama Mystery Thriller Crime
# 247  Thriller Science Fiction Action Adventure
# 248                              Drama History
# 249                                  Drama War
#
# [250 rows x 7 columns]

# %%
df_2018 = df[['Title', 'Cast and crew', 'genres']]
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 245               Second Act
# 246          Holmes & Watson
# 247                     Vice
# 248      On the Basis of Sex
# 249                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 245  Peter Segal (director); Justin Zackham, Elaine...
# 246  Etan Cohen (director/screenplay); Will Ferrell...
# 247  Adam McKay (director/screenplay); Christian Ba...
# 248  Mimi Leder (director); Daniel Stiepleman (scre...
# 249  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                                         genres
# 0                              Horror Thriller
# 1                               Thriller Drama
# 2                      Action Thriller Mystery
# 3                        Thriller Action Crime
# 4                  Action Drama Crime Thriller
# ..                                         ...
# 245                             Romance Comedy
# 246               Drama Mystery Thriller Crime
# 247  Thriller Science Fiction Action Adventure
# 248                              Drama History
# 249                                  Drama War
#
# [250 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x : get_director(x))
# Out:
# /var/folders/78/67qsv_654q11y5bbd4d1vb200000gn/T/ipykernel_2143/3300182342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x : get_director(x))

# %%
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 245               Second Act
# 246          Holmes & Watson
# 247                     Vice
# 248      On the Basis of Sex
# 249                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 245  Peter Segal (director); Justin Zackham, Elaine...
# 246  Etan Cohen (director/screenplay); Will Ferrell...
# 247  Adam McKay (director/screenplay); Christian Ba...
# 248  Mimi Leder (director); Daniel Stiepleman (scre...
# 249  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                                         genres  \
# 0                              Horror Thriller
# 1                               Thriller Drama
# 2                      Action Thriller Mystery
# 3                        Thriller Action Crime
# 4                  Action Drama Crime Thriller
# ..                                         ...
# 245                             Romance Comedy
# 246               Drama Mystery Thriller Crime
# 247  Thriller Science Fiction Action Adventure
# 248                              Drama History
# 249                                  Drama War
#
#                                          director_name
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 245                                        Peter Segal
# 246                                         Etan Cohen
# 247                                         Adam McKay
# 248                                         Mimi Leder
# 249                                       Karyn Kusama
#
# [250 rows x 4 columns]

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(', ')[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x : get_actor1(x))
# Out:
# /var/folders/78/67qsv_654q11y5bbd4d1vb200000gn/T/ipykernel_2143/1998695760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x : get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(', ')) < 2:
        return np.NAN
    else:
        return ((x.split('screenplay); ')[-1]).split(', ')[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x : get_actor2(x))
# Out:
# /var/folders/78/67qsv_654q11y5bbd4d1vb200000gn/T/ipykernel_2143/3334561699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x : get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split(' screenplay; ')[-1]).split(', ')) < 3:
        return np.NAN
    else:
        return ((x.split(' screenplay); ')[-1]).split(', ')[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x : get_actor3(x))

# %%
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 245               Second Act
# 246          Holmes & Watson
# 247                     Vice
# 248      On the Basis of Sex
# 249                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 245  Peter Segal (director); Justin Zackham, Elaine...
# 246  Etan Cohen (director/screenplay); Will Ferrell...
# 247  Adam McKay (director/screenplay); Christian Ba...
# 248  Mimi Leder (director); Daniel Stiepleman (scre...
# 249  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                                         genres  \
# 0                              Horror Thriller
# 1                               Thriller Drama
# 2                      Action Thriller Mystery
# 3                        Thriller Action Crime
# 4                  Action Drama Crime Thriller
# ..                                         ...
# 245                             Romance Comedy
# 246               Drama Mystery Thriller Crime
# 247  Thriller Science Fiction Action Adventure
# 248                              Drama History
# 249                                  Drama War
#
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 245                                        Peter Segal
# 246                                         Etan Cohen
# 247                                         Adam McKay
# 248                                         Mimi Leder
# 249                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 245                              Jennifer Lopez             Leah Remini
# 246                                Will Ferrell          John C. Reilly
# 247                              Christian Bale               Amy Adams
# 248                              Felicity Jones            Armie Hammer
# 249                               Nicole Kidman          Sebastian Stan
#
#                                    actor_3_name
# 0                                Leigh Whannell
# 1                                 Emily Althaus
# 2          Ryan Engle (screenplay); Liam Neeson
# 3    Steve Antin (screenplay); Taraji P. Henson
# 4                                 Shawn Ashmore
# ..                                          ...
# 245                                 Leah Remini
# 246                                Rebecca Hall
# 247                                Steve Carell
# 248                              Justin Theroux
# 249                              Sebastian Stan
#
# [250 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns = {'Title' : 'movie_title'})

# %%
new_df18 = df_2018.loc[:, ["director_name", "actor_1_name", "actor_2_name", "actor_3_name", "genres", "movie_title"]]

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 245                                        Peter Segal
# 246                                         Etan Cohen
# 247                                         Adam McKay
# 248                                         Mimi Leder
# 249                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 245                              Jennifer Lopez             Leah Remini
# 246                                Will Ferrell          John C. Reilly
# 247                              Christian Bale               Amy Adams
# 248                              Felicity Jones            Armie Hammer
# 249                               Nicole Kidman          Sebastian Stan
#
#                                    actor_3_name  \
# 0                                Leigh Whannell
# 1                                 Emily Althaus
# 2          Ryan Engle (screenplay); Liam Neeson
# 3    Steve Antin (screenplay); Taraji P. Henson
# 4                                 Shawn Ashmore
# ..                                          ...
# 245                                 Leah Remini
# 246                                Rebecca Hall
# 247                                Steve Carell
# 248                              Justin Theroux
# 249                              Sebastian Stan
#
#                                         genres              movie_title
# 0                              Horror Thriller  Insidious: The Last Key
# 1                               Thriller Drama         The Strange Ones
# 2                      Action Thriller Mystery             The Commuter
# 3                        Thriller Action Crime               Proud Mary
# 4                  Action Drama Crime Thriller         Acts of Violence
# ..                                         ...                      ...
# 245                             Romance Comedy               Second Act
# 246               Drama Mystery Thriller Crime          Holmes & Watson
# 247  Thriller Science Fiction Action Adventure                     Vice
# 248                              Drama History      On the Basis of Sex
# 249                                  Drama War                Destroyer
#
# [250 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' ' + new_df18['actor_3_name'] + ' ' + new_df18['director_name'] + ' ' + new_df18['genres']
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 245                                        Peter Segal
# 246                                         Etan Cohen
# 247                                         Adam McKay
# 248                                         Mimi Leder
# 249                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 245                              Jennifer Lopez             Leah Remini
# 246                                Will Ferrell          John C. Reilly
# 247                              Christian Bale               Amy Adams
# 248                              Felicity Jones            Armie Hammer
# 249                               Nicole Kidman          Sebastian Stan
#
#                                    actor_3_name  \
# 0                                Leigh Whannell
# 1                                 Emily Althaus
# 2          Ryan Engle (screenplay); Liam Neeson
# 3    Steve Antin (screenplay); Taraji P. Henson
# 4                                 Shawn Ashmore
# ..                                          ...
# 245                                 Leah Remini
# 246                                Rebecca Hall
# 247                                Steve Carell
# 248                              Justin Theroux
# 249                              Sebastian Stan
#
#                                         genres              movie_title  \
# 0                              Horror Thriller  insidious: the last key
# 1                               Thriller Drama         the strange ones
# 2                      Action Thriller Mystery             the commuter
# 3                        Thriller Action Crime               proud mary
# 4                  Action Drama Crime Thriller         acts of violence
# ..                                         ...                      ...
# 245                             Romance Comedy               second act
# 246               Drama Mystery Thriller Crime          holmes & watson
# 247  Thriller Science Fiction Action Adventure                     vice
# 248                              Drama History      on the basis of sex
# 249                                  Drama War                destroyer
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Ryan Engle (screenpla...
# 3    Taraji P. Henson Jahi Di'Allo Winston Steve An...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 245  Jennifer Lopez Leah Remini Leah Remini Peter S...
# 246  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 247  Christian Bale Amy Adams Steve Carell Adam McK...
# 248  Felicity Jones Armie Hammer Justin Theroux Mim...
# 249  Nicole Kidman Sebastian Stan Sebastian Stan Ka...
#
# [250 rows x 7 columns]

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header = 0)[2]
df2 = pd.read_html(link, header = 0)[3]
df3 = pd.read_html(link, header = 0)[4]
df4 = pd.read_html(link, header = 0)[5]

# %%
df = pd.concat([df1, pd.concat([df2, pd.concat([df3, df4], ignore_index = True)], ignore_index = True)], ignore_index = True)
df
# Out:
#              Opening Opening.1              Title  \
# 0      J A N U A R Y         4        Escape Room
# 1      J A N U A R Y         4         Rust Creek
# 2      J A N U A R Y         4   American Hangman
# 3      J A N U A R Y        11   A Dog's Way Home
# 4      J A N U A R Y        11         The Upside
# ..               ...       ...                ...
# 245  D E C E M B E R        25  Spies in Disguise
# 246  D E C E M B E R        25       Little Women
# 247  D E C E M B E R        25               1917
# 248  D E C E M B E R        25         Just Mercy
# 249  D E C E M B E R        27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 245  20th Century Fox Animation / Blue Sky Studios ...
# 246            Columbia Pictures / Regency Enterprises
# 247           Universal Pictures / DreamWorks Pictures
# 248                Warner Bros. Pictures / Participant
# 249                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 245  Nick Bruno, Troy Quane (directors); Brad Copel...  [133]
# 246  Greta Gerwig (director/screenplay); Saoirse Ro...  [226]
# 247  Sam Mendes (director/screenplay); Krysty Wilso...  [227]
# 248  Destin Daniel Cretton (director/screenplay), A...  [228]
# 249  Chinonye Chukwu (director/screenplay); Alfre W...  [229]
#
# [250 rows x 6 columns]

# %%
df
# Out:
#              Opening Opening.1              Title  \
# 0      J A N U A R Y         4        Escape Room
# 1      J A N U A R Y         4         Rust Creek
# 2      J A N U A R Y         4   American Hangman
# 3      J A N U A R Y        11   A Dog's Way Home
# 4      J A N U A R Y        11         The Upside
# ..               ...       ...                ...
# 245  D E C E M B E R        25  Spies in Disguise
# 246  D E C E M B E R        25       Little Women
# 247  D E C E M B E R        25               1917
# 248  D E C E M B E R        25         Just Mercy
# 249  D E C E M B E R        27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 245  20th Century Fox Animation / Blue Sky Studios ...
# 246            Columbia Pictures / Regency Enterprises
# 247           Universal Pictures / DreamWorks Pictures
# 248                Warner Bros. Pictures / Participant
# 249                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 245  Nick Bruno, Troy Quane (directors); Brad Copel...  [133]
# 246  Greta Gerwig (director/screenplay); Saoirse Ro...  [226]
# 247  Sam Mendes (director/screenplay); Krysty Wilso...  [227]
# 248  Destin Daniel Cretton (director/screenplay), A...  [228]
# 249  Chinonye Chukwu (director/screenplay); Alfre W...  [229]
#
# [250 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x : get_genre(str(x)))

# %%
df_2019 = df[['Title', 'Cast and crew', 'genres']]
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 245  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 246       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 247               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 248         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 249           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# 0                             Horror Thriller
# 1                 Thriller Drama Action Crime
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 245  Animation Action Adventure Comedy Family
# 246                     Drama Romance History
# 247                War History Thriller Drama
# 248                       Drama Crime History
# 249                                     Drama
#
# [250 rows x 3 columns]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x : get_director(str(x)))
# Out:
# /var/folders/78/67qsv_654q11y5bbd4d1vb200000gn/T/ipykernel_2143/3119375035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x : get_director(str(x)))

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x : get_actor1(x))
# Out:
# /var/folders/78/67qsv_654q11y5bbd4d1vb200000gn/T/ipykernel_2143/2256786618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x : get_actor1(x))

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x : get_actor2(x))
# Out:
# /var/folders/78/67qsv_654q11y5bbd4d1vb200000gn/T/ipykernel_2143/3520282211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x : get_actor2(x))

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x : get_actor3(x))

# %%
df_2019 = df_2019.rename(columns = {'Title' : 'movie_title'})

# %%
new_df19 = df_2019.loc[:, ['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'genres','movie_title']]

# %%
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 245  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 246            Greta Gerwig        Saoirse Ronan           Emma Watson
# 247              Sam Mendes        George MacKay  Dean-Charles Chapman
# 248   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 249         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#         actor_3_name                                    genres  \
# 0       Logan Miller                           Horror Thriller
# 1       Sean O'Bryan               Thriller Drama Action Crime
# 2      Oliver Dennis                                  Thriller
# 3    Alexandra Shipp                    Drama Adventure Family
# 4      Nicole Kidman                              Comedy Drama
# ..               ...                                       ...
# 245      Tom Holland  Animation Action Adventure Comedy Family
# 246    Florence Pugh                     Drama Romance History
# 247      Mark Strong                War History Thriller Drama
# 248       Jamie Foxx                       Drama Crime History
# 249      Aldis Hodge                                     Drama
#
#            movie_title
# 0          Escape Room
# 1           Rust Creek
# 2     American Hangman
# 3     A Dog's Way Home
# 4           The Upside
# ..                 ...
# 245  Spies in Disguise
# 246       Little Women
# 247               1917
# 248         Just Mercy
# 249           Clemency
#
# [250 rows x 6 columns]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' ' + new_df19['actor_3_name'] + ' ' + new_df19['director_name'] + ' ' + new_df19['genres']
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 245  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 246            Greta Gerwig        Saoirse Ronan           Emma Watson
# 247              Sam Mendes        George MacKay  Dean-Charles Chapman
# 248   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 249         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#         actor_3_name                                    genres  \
# 0       Logan Miller                           Horror Thriller
# 1       Sean O'Bryan               Thriller Drama Action Crime
# 2      Oliver Dennis                                  Thriller
# 3    Alexandra Shipp                    Drama Adventure Family
# 4      Nicole Kidman                              Comedy Drama
# ..               ...                                       ...
# 245      Tom Holland  Animation Action Adventure Comedy Family
# 246    Florence Pugh                     Drama Romance History
# 247      Mark Strong                War History Thriller Drama
# 248       Jamie Foxx                       Drama Crime History
# 249      Aldis Hodge                                     Drama
#
#            movie_title                                               comb
# 0          escape room  Taylor Russell Logan Miller Logan Miller Adam ...
# 1           rust creek  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2     american hangman  Donald Sutherland Vincent Kartheiser Oliver De...
# 3     a dog's way home  Bryce Dallas Howard Edward James Olmos Alexand...
# 4           the upside  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                 ...                                                ...
# 245  spies in disguise  Will Smith Tom Holland Tom Holland Nick Bruno,...
# 246       little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 247               1917  George MacKay Dean-Charles Chapman Mark Strong...
# 248         just mercy  Michael B. Jordan Jamie Foxx Jamie Foxx Destin...
# 249           clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [250 rows x 7 columns]

# %%
my_df = pd.concat([new_df18, new_df19], ignore_index = True)
my_df
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 495                             Nick Bruno, Troy Quane
# 496                                       Greta Gerwig
# 497                                         Sam Mendes
# 498                              Destin Daniel Cretton
# 499                                    Chinonye Chukwu
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 495                                  Will Smith             Tom Holland
# 496                               Saoirse Ronan             Emma Watson
# 497                               George MacKay    Dean-Charles Chapman
# 498                           Michael B. Jordan              Jamie Foxx
# 499                               Alfre Woodard          Wendell Pierce
#
#                                    actor_3_name  \
# 0                                Leigh Whannell
# 1                                 Emily Althaus
# 2          Ryan Engle (screenplay); Liam Neeson
# 3    Steve Antin (screenplay); Taraji P. Henson
# 4                                 Shawn Ashmore
# ..                                          ...
# 495                                 Tom Holland
# 496                               Florence Pugh
# 497                                 Mark Strong
# 498                                  Jamie Foxx
# 499                                 Aldis Hodge
#
#                                        genres              movie_title  \
# 0                             Horror Thriller  insidious: the last key
# 1                              Thriller Drama         the strange ones
# 2                     Action Thriller Mystery             the commuter
# 3                       Thriller Action Crime               proud mary
# 4                 Action Drama Crime Thriller         acts of violence
# ..                                        ...                      ...
# 495  Animation Action Adventure Comedy Family        spies in disguise
# 496                     Drama Romance History             little women
# 497                War History Thriller Drama                     1917
# 498                       Drama Crime History               just mercy
# 499                                     Drama                 clemency
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Ryan Engle (screenpla...
# 3    Taraji P. Henson Jahi Di'Allo Winston Steve An...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 495  Will Smith Tom Holland Tom Holland Nick Bruno,...
# 496  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 497  George MacKay Dean-Charles Chapman Mark Strong...
# 498  Michael B. Jordan Jamie Foxx Jamie Foxx Destin...
# 499  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [500 rows x 7 columns]

# %%
old_df = pd.read_csv('/Users/arunabhapani/Desktop/netflix_movie_recommendation_system/new_data.csv')

# %%
final_df = pd.concat([old_df, my_df], ignore_index = True)

# %%
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5859  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5860            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5861              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5862   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5863         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5859           Tom Holland  Animation Action Adventure Comedy Family
# 5860         Florence Pugh                     Drama Romance History
# 5861           Mark Strong                War History Thriller Drama
# 5862            Jamie Foxx                       Drama Crime History
# 5863           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5859                                  spies in disguise
# 5860                                       little women
# 5861                                               1917
# 5862                                         just mercy
# 5863                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5859  Will Smith Tom Holland Tom Holland Nick Bruno,...
# 5860  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5861  George MacKay Dean-Charles Chapman Mark Strong...
# 5862  Michael B. Jordan Jamie Foxx Jamie Foxx Destin...
# 5863  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5864 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           1
# movie_title      0
# comb             1
# dtype: int64

# %%
final_df = final_df.dropna(how = 'any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv', index = False)
